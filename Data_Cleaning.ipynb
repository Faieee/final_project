# %%
#add magic command
# %matplotlib inline 

# Dependencies and Setup
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import statistics

# %%
# File to Load 
census_data_to_load = os.path.join('census_data.csv')

# Read the  Data and store into a Pandas DataFrame
census_data_df = pd.read_csv(census_data_to_load)
census_data_df
# Out:
#        Unnamed: 0  age          workclass  fnlwgt    education  education_num  \
# 0               0   39          State-gov   77516    Bachelors             13
# 1               1   50   Self-emp-not-inc   83311    Bachelors             13
# 2               2   38            Private  215646      HS-grad              9
# 3               3   53            Private  234721         11th              7
# 4               4   28            Private  338409    Bachelors             13
# ...           ...  ...                ...     ...          ...            ...
# 32556       32556   27            Private  257302   Assoc-acdm             12
# 32557       32557   40            Private  154374      HS-grad              9
# 32558       32558   58            Private  151910      HS-grad              9
# 32559       32559   22            Private  201490      HS-grad              9
# 32560       32560   52       Self-emp-inc  287927      HS-grad              9
#
# ...

# %%
# Determine data types 
census_data_df.dtypes
# Out:
# Unnamed: 0         int64
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital_gain       int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# income            object
# dtype: object

# %%
# Determine workclass level

workclass_types = census_data_df.set_index(["workclass"])["income"]
workclass_types
# Out:
# workclass
#  State-gov            <=50K
#  Self-emp-not-inc     <=50K
#  Private              <=50K
#  Private              <=50K
#  Private              <=50K
#                       ...
#  Private              <=50K
#  Private               >50K
#  Private              <=50K
#  Private              <=50K
#  Self-emp-inc          >50K
# Name: income, Length: 32561, dtype: object

# %%
# Calculate averages for the desired columns.

State-gov_salary = census_data_df.groupby(["state-gov"]).mean()["Average income"]
self-emp-not-inc_salary = census_data_df.groupby(["self-emp-not-inc"]).mean()["Average income"]
# Out:
#   File "C:\Users\lina2\AppData\Local\Temp\ipykernel_10268\1613507241.py", line 4
#     self-emp-not-inc_salary = census_data_df.groupby(["self-emp-not-inc"]).mean()["Average income"]
#                ^
# SyntaxError: invalid syntax

# %%
# group by workclass category
workclass_count = census_data_df.groupby('workclass')['education'].count()
print(workclass_count)
# Out:
# workclass
#  ?                    1836
#  Federal-gov           960
#  Local-gov            2093
#  Never-worked            7
#  Private             22696
#  Self-emp-inc         1116
#  Self-emp-not-inc     2541
#  State-gov            1298
#  Without-pay            14
# Name: education, dtype: int64

# %%
# Determine education level

education_level_types = census_data_df.set_index(["education"])["income"]
education_level_types
# Out:
# education
#  Bachelors      <=50K
#  Bachelors      <=50K
#  HS-grad        <=50K
#  11th           <=50K
#  Bachelors      <=50K
#                 ...
#  Assoc-acdm     <=50K
#  HS-grad         >50K
#  HS-grad        <=50K
#  HS-grad        <=50K
#  HS-grad         >50K
# Name: income, Length: 32561, dtype: object

# %%
# group by education category
Education_level_count = census_data_df.groupby('education')['education'].count()
print(Education_level_count)
# Out:
# education
#  10th              933
#  11th             1175
#  12th              433
#  1st-4th           168
#  5th-6th           333
#  7th-8th           646
#  9th               514
#  Assoc-acdm       1067
#  Assoc-voc        1382
#  Bachelors        5355
#  Doctorate         413
#  HS-grad         10501
#  Masters          1723
#  Preschool          51
#  Prof-school       576
#  Some-college     7291
# Name: education, dtype: int64
