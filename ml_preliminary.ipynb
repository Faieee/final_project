# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
df = pd.read_csv('census_data.csv')
df
# Out:
#        Unnamed: 0  age          workclass  fnlwgt    education  education_num  \
# 0               0   39          State-gov   77516    Bachelors             13
# 1               1   50   Self-emp-not-inc   83311    Bachelors             13
# 2               2   38            Private  215646      HS-grad              9
# 3               3   53            Private  234721         11th              7
# 4               4   28            Private  338409    Bachelors             13
# ...           ...  ...                ...     ...          ...            ...
# 32556       32556   27            Private  257302   Assoc-acdm             12
# 32557       32557   40            Private  154374      HS-grad              9
# 32558       32558   58            Private  151910      HS-grad              9
# 32559       32559   22            Private  201490      HS-grad              9
# 32560       32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 16 columns]

# %%
df.education.unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
df.groupby(df['hours_per_week']).count().head(40)
# Out:
#                 Unnamed: 0    age  workclass  fnlwgt  education  \
# hours_per_week
# 1                       20     20         20      20         20
# 2                       32     32         32      32         32
# 3                       39     39         39      39         39
# 4                       54     54         54      54         54
# 5                       60     60         60      60         60
# 6                       64     64         64      64         64
# 7                       26     26         26      26         26
# 8                      145    145        145     145        145
# 9                       18     18         18      18         18
# 10                     278    278        278     278        278
# 11                      11     11         11      11         11
# 12                     173    173        173     173        173
# 13                      23     23         23      23         23
# 14                      34     34         34      34         34
# 15                     404    404        404     404        404
# 16                     205    205        205     205        205
# 17                      29     29         29      29         29
# 18                      75     75         75      75         75
# 19                      14     14         14      14         14
# 20                    1224   1224       1224    1224       1224
# 21                      24     24         24      24         24
# 22                      44     44         44      44         44
# 23                      21     21         21      21         21
# 24                     252    252        252     252        252
# 25                     674    674        674     674        674
# 26                      30     30         30      30         30
# 27                      30     30         30      30         30
# 28                      86     86         86      86         86
# 29                       7      7          7       7          7
# 30                    1149   1149       1149    1149       1149
# 31                       5      5          5       5          5
# 32                     266    266        266     266        266
# 33                      39     39         39      39         39
# 34                      28     28         28      28         28
# 35                    1297   1297       1297    1297       1297
# 36                     220    220        220     220        220
# 37                     149    149        149     149        149
# 38                     476    476        476     476        476
# 39                      38     38         38      38         38
# 40                   15217  15217      15217   15217      15217
#
#                 education_num  marital_status  occupation  relationship  \
# hours_per_week
# 1                          20              20          20            20
# 2                          32              32          32            32
# 3                          39              39          39            39
# 4                          54              54          54            54
# 5                          60              60          60            60
# 6                          64              64          64            64
# 7                          26              26          26            26
# 8                         145             145         145           145
# 9                          18              18          18            18
# 10                        278             278         278           278
# 11                         11              11          11            11
# 12                        173             173         173           173
# 13                         23              23          23            23
# 14                         34              34          34            34
# 15                        404             404         404           404
# 16                        205             205         205           205
# 17                         29              29          29            29
# 18                         75              75          75            75
# 19                         14              14          14            14
# 20                       1224            1224        1224          1224
# 21                         24              24          24            24
# 22                         44              44          44            44
# 23                         21              21          21            21
# 24                        252             252         252           252
# 25                        674             674         674           674
# 26                         30              30          30            30
# 27                         30              30          30            30
# 28                         86              86          86            86
# 29                          7               7           7             7
# 30                       1149            1149        1149          1149
# 31                          5               5           5             5
# 32                        266             266         266           266
# 33                         39              39          39            39
# 34                         28              28          28            28
# 35                       1297            1297        1297          1297
# 36                        220             220         220           220
# 37                        149             149         149           149
# 38                        476             476         476           476
# 39                         38              38          38            38
# 40                      15217           15217       15217         15217
#
#                  race    sex  capital_gain  capital_loss  native_country  \
# hours_per_week
# 1                  20     20            20            20              20
# 2                  32     32            32            32              32
# 3                  39     39            39            39              39
# 4                  54     54            54            54              54
# 5                  60     60            60            60              60
# 6                  64     64            64            64              64
# 7                  26     26            26            26              26
# 8                 145    145           145           145             145
# 9                  18     18            18            18              18
# 10                278    278           278           278             278
# 11                 11     11            11            11              11
# 12                173    173           173           173             173
# 13                 23     23            23            23              23
# 14                 34     34            34            34              34
# 15                404    404           404           404             404
# 16                205    205           205           205             205
# 17                 29     29            29            29              29
# 18                 75     75            75            75              75
# 19                 14     14            14            14              14
# 20               1224   1224          1224          1224            1224
# 21                 24     24            24            24              24
# 22                 44     44            44            44              44
# 23                 21     21            21            21              21
# 24                252    252           252           252             252
# 25                674    674           674           674             674
# 26                 30     30            30            30              30
# 27                 30     30            30            30              30
# 28                 86     86            86            86              86
# 29                  7      7             7             7               7
# 30               1149   1149          1149          1149            1149
# 31                  5      5             5             5               5
# 32                266    266           266           266             266
# 33                 39     39            39            39              39
# 34                 28     28            28            28              28
# 35               1297   1297          1297          1297            1297
# 36                220    220           220           220             220
# 37                149    149           149           149             149
# 38                476    476           476           476             476
# 39                 38     38            38            38              38
# 40              15217  15217         15217         15217           15217
#
#                 income
# hours_per_week
# 1                   20
# 2                   32
# 3                   39
# 4                   54
# 5                   60
# 6                   64
# 7                   26
# 8                  145
# 9                   18
# 10                 278
# 11                  11
# 12                 173
# 13                  23
# 14                  34
# 15                 404
# 16                 205
# 17                  29
# 18                  75
# 19                  14
# 20                1224
# 21                  24
# 22                  44
# 23                  21
# 24                 252
# 25                 674
# 26                  30
# 27                  30
# 28                  86
# 29                   7
# 30                1149
# 31                   5
# 32                 266
# 33                  39
# 34                  28
# 35                1297
# 36                 220
# 37                 149
# 38                 476
# 39                  38
# 40               15217

# %%
# choose data 

le = LabelEncoder()
df_raw = df[['age', 'workclass', 'education_num', 'marital_status', 'occupation', 'relationship', 'race', 'sex', 'income']]

df_raw
# Out:
#        age          workclass  education_num       marital_status  \
# 0       39          State-gov             13        Never-married
# 1       50   Self-emp-not-inc             13   Married-civ-spouse
# 2       38            Private              9             Divorced
# 3       53            Private              7   Married-civ-spouse
# 4       28            Private             13   Married-civ-spouse
# ...    ...                ...            ...                  ...
# 32556   27            Private             12   Married-civ-spouse
# 32557   40            Private              9   Married-civ-spouse
# 32558   58            Private              9              Widowed
# 32559   22            Private              9        Never-married
# 32560   52       Self-emp-inc              9   Married-civ-spouse
#
#                occupation    relationship    race      sex  income
# 0            Adm-clerical   Not-in-family   White     Male   <=50K
# 1         Exec-managerial         Husband   White     Male   <=50K
# 2       Handlers-cleaners   Not-in-family   White     Male   <=50K
# 3       Handlers-cleaners         Husband   Black     Male   <=50K
# 4          Prof-specialty            Wife   Black   Female   <=50K
# ...                   ...             ...     ...      ...     ...
# 32556        Tech-support            Wife   White   Female   <=50K
# 32557   Machine-op-inspct         Husband   White     Male    >50K
# 32558        Adm-clerical       Unmarried   White   Female   <=50K
# 32559        Adm-clerical       Own-child   White     Male   <=50K
# 32560     Exec-managerial            Wife   White   Female    >50K
#
# [32561 rows x 9 columns]

# %%
# encode data

df_encoded = df_raw.copy()

for column in df_raw.columns:
    df_encoded[f'{column}'] = le.fit_transform(df_encoded[f'{column}'])

# %%
df_encoded
# Out:
#        age  workclass  education_num  marital_status  occupation  \
# 0       22          7             12               4           1
# 1       33          6             12               2           4
# 2       21          4              8               0           6
# 3       36          4              6               2           6
# 4       11          4             12               2          10
# ...    ...        ...            ...             ...         ...
# 32556   10          4             11               2          13
# 32557   23          4              8               2           7
# 32558   41          4              8               6           1
# 32559    5          4              8               4           1
# 32560   35          5              8               2           4
#
#        relationship  race  sex  income
# 0                 1     4    1       0
# 1                 0     4    1       0
# 2                 1     4    1       0
# 3                 0     2    1       0
# 4                 5     2    0       0
# ...             ...   ...  ...     ...
# 32556             5     4    0       0
# 32557             0     4    1       1
# 32558             4     4    0       0
# 32559             3     4    1       0
# 32560             5     4    0       1
#
# [32561 rows x 9 columns]

# %%
# prepare ml data

X = df_encoded.drop(columns='income')
y = df_encoded['income']

# %%
# split data

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y)

# %%
classifier = LogisticRegression(solver='lbfgs', max_iter=500)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=500)

# %%
y_pred = classifier.predict(X_test)

# %%
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.7957253408672154
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87      6181
#            1       0.63      0.38      0.47      1960
#
#     accuracy                           0.80      8141
#    macro avg       0.73      0.65      0.67      8141
# weighted avg       0.78      0.80      0.78      8141

# %% [markdown]
# ## I'll try only using data at 40 hours worked per week

# %%
df_raw_w_hours = df[['age', 'workclass', 'education_num', 'marital_status', 
                     'occupation', 'relationship', 'race', 'sex', 'hours_per_week', 'income']]
df_raw_40hours = df_raw_w_hours[df_raw_w_hours['hours_per_week'] == 40].drop(columns='hours_per_week')

# %%
df_raw_40hours
# Out:
#        age      workclass  education_num       marital_status  \
# 0       39      State-gov             13        Never-married
# 2       38        Private              9             Divorced
# 3       53        Private              7   Married-civ-spouse
# 4       28        Private             13   Married-civ-spouse
# 5       37        Private             14   Married-civ-spouse
# ...    ...            ...            ...                  ...
# 32554   53        Private             14   Married-civ-spouse
# 32555   22        Private             10        Never-married
# 32557   40        Private              9   Married-civ-spouse
# 32558   58        Private              9              Widowed
# 32560   52   Self-emp-inc              9   Married-civ-spouse
#
#                occupation    relationship    race      sex  income
# 0            Adm-clerical   Not-in-family   White     Male   <=50K
# 2       Handlers-cleaners   Not-in-family   White     Male   <=50K
# 3       Handlers-cleaners         Husband   Black     Male   <=50K
# 4          Prof-specialty            Wife   Black   Female   <=50K
# 5         Exec-managerial            Wife   White   Female   <=50K
# ...                   ...             ...     ...      ...     ...
# 32554     Exec-managerial         Husband   White     Male    >50K
# 32555     Protective-serv   Not-in-family   White     Male   <=50K
# 32557   Machine-op-inspct         Husband   White     Male    >50K
# 32558        Adm-clerical       Unmarried   White   Female   <=50K
# 32560     Exec-managerial            Wife   White   Female    >50K
#
# [15217 rows x 9 columns]

# %%
# encode 40 hours dataset

df_encoded = df_raw_40hours.copy()

for column in df_raw_40hours.columns:
    df_encoded[f'{column}'] = le.fit_transform(df_encoded[f'{column}'])

# %%
# split data

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y)

classifier = LogisticRegression(solver='lbfgs', max_iter=500)
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.8057978135364205
#               precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88      6181
#            1       0.67      0.38      0.48      1960
#
#     accuracy                           0.81      8141
#    macro avg       0.75      0.66      0.68      8141
# weighted avg       0.79      0.81      0.79      8141

# %% [markdown]
# ## using balanced random forest

# %%
from imblearn.ensemble import BalancedRandomForestClassifier
brfc = BalancedRandomForestClassifier(n_estimators=100)

# %%
brfc.fit(X_train, y_train)
y_pred = brfc.predict(X_test)

# %%
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.7838103427097408
#               precision    recall  f1-score   support
#
#            0       0.93      0.77      0.84      6181
#            1       0.53      0.82      0.65      1960
#
#     accuracy                           0.78      8141
#    macro avg       0.73      0.80      0.74      8141
# weighted avg       0.83      0.78      0.80      8141

# %%
sorted(zip(brfc.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.3198339294807274, 'age'),
#  (0.17434897107055725, 'education_num'),
#  (0.1425715762455719, 'relationship'),
#  (0.1380786108380267, 'marital_status'),
#  (0.11693416889202268, 'occupation'),
#  (0.059685080642327096, 'workclass'),
#  (0.024866263302724467, 'sex'),
#  (0.023681399528042463, 'race')]
